# %% [markdown]
# ### CardioGuard -- Dashboard Export

# %%
import os
import pandas as pd
import numpy as np

DATA_PROCESSED = os.path.join("..", "data", "processed")

# %% [markdown]
# ### STEP 1 - Load final modelling dataset

# %%
df = pd.read_csv(
    os.path.join(DATA_PROCESSED, "cardioguard_model_features.csv")
)

df.head()

# %% [markdown]
# ### STEP 2 - Create dashboard risk band   b b      nb vb

# %%
df["risk_band"] = df["high_risk_flag"].map({
    0: "Lower / Moderate Risk",
    1: "High Risk"
})

# %%
:@{qzAXCV }
